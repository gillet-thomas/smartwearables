# %% [markdown]
# This Google Colab notebook is the implementation of the Smart Wearables project.Further information about this project can be found on my Github here:
# https://github.com/gillet-thomas/smartwearables/
#
# Please note that this notebook only allows to generate the sequence of images and doesn't provide a real-time video output.

# %% [markdown]
# # Setup

# %%
## Connect to Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
## Clone repository
# !git clone https://github.com/gillet-thomas/smartwearables
# %cd smartwearables

# %%
## Install CUDA
# !pip install -q condacolab
import condacolab
condacolab.install()
# !conda --version

# %%
## FRANKMOCAP Basic Installation
# !conda install cudatoolkit=10.1 cudnn=7.6.0
# !conda install -c pytorch pytorch==1.6.0 torchvision cudatoolkit=10.1
# !pip install -r docs/requirements.txt

# !pip install torchgeometry
# !pip install imutils
# !pip install opencv-python

# %%
## Install 2D keypoint detector
# !sh scripts/install_pose2d.sh

## Import extra_data from Google Drive
# !mkdir extra_data/
# !cp -a /content/drive/MyDrive/smartwearables/extra_data/. extra_data/

# %% [markdown]
# # Run demo

# %%
# Install xvfb
! sudo apt-get update -y
! sudo apt-get install -y xvfb

# %%
# !xvfb-run -a python -m demo.demo_bodymocap_colab --input_path ./data/input_videos/han_long.mp4 --out_dir ./mocap_output
